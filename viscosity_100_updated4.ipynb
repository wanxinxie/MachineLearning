# %%
import pandas as pd
import numpy as np 

from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import statistics 
from tqdm import tqdm

# %%
viscosity = pd.read_excel("viscosity_v5_100.xlsx")

# %%
viscosity
# Out:
#        Glass_ID       SiO2  B2O3  Al2O3  ...  prop_id   unit  note  source
# 0            26  66.199997  4.34   1.81  ...     1210  Poise   NaN   inter
# 1            26  66.199997  4.34   1.81  ...     1211  Poise   NaN   inter
# 2            26  66.199997  4.34   1.81  ...     1212  Poise   NaN   inter
# 3            26  66.199997  4.34   1.81  ...     1213  Poise   NaN   inter
# 4            26  66.199997  4.34   1.81  ...     1214  Poise   NaN   inter
# ...         ...        ...   ...    ...  ...      ...    ...   ...     ...
# 98156   1011794  72.320000  0.00   9.99  ...     1215  Poise   NaN     sci
# 98157   1011794  72.320000  0.00   9.99  ...     1216  Poise   NaN     sci
# 98158   1032638  66.629997  0.00  13.77  ...     1214  Poise   NaN     sci
# 98159   1032638  66.629997  0.00  13.77  ...     1215  Poise   NaN     sci
# 98160   1032638  66.629997  0.00  13.77  ...     1216  Poise   NaN     sci
#
# [98161 rows x 60 columns]

# %%
X_idx=[]
for i in range(1,54):
  X_idx.append(i)
X_idx.append(55)

# %%
 viscosity.iloc[range(14790,93231),:]
# Out:
#        Glass_ID       SiO2  B2O3  Al2O3  ...  prop_id   unit     note  source
# 14790    232668   0.000000  64.0   0.00  ...     1221  Poise  at 773C   inter
# 14791    232669   0.000000  62.0   0.00  ...     1221  Poise  at 840C   inter
# 14792    232670   0.000000  61.0   0.00  ...     1221  Poise  at 875C   inter
# 14793    232671   0.000000  60.0   0.00  ...     1209  Poise  at 895C   inter
# 14794    232672   0.000000  56.0   0.00  ...     1221  Poise  at 947C   inter
# ...         ...        ...   ...    ...  ...      ...    ...      ...     ...
# 93226    899890  66.419998   0.3  14.69  ...     1212  Poise      NaN     sci
# 93227    899890  66.419998   0.3  14.69  ...     1213  Poise      NaN     sci
# 93228    899890  66.419998   0.3  14.69  ...     1214  Poise      NaN     sci
# 93229    899890  66.419998   0.3  14.69  ...     1215  Poise      NaN     sci
# 93230    899890  66.419998   0.3  14.69  ...     1216  Poise      NaN     sci
#
# [78441 rows x 60 columns]

# %%
testing = viscosity.drop(range(14790,93231)).iloc[:,X_idx] # 9861,88305
testing
# Out:
#             SiO2  B2O3  Al2O3        MgO  ...  MoO3  WO3  H2O  Temperature_C
# 0      66.199997  4.34   1.81   4.740000  ...   0.0  0.0  0.0         1000.0
# 1      66.199997  4.34   1.81   4.740000  ...   0.0  0.0  0.0         1100.0
# 2      66.199997  4.34   1.81   4.740000  ...   0.0  0.0  0.0         1200.0
# 3      66.199997  4.34   1.81   4.740000  ...   0.0  0.0  0.0         1300.0
# 4      66.199997  4.34   1.81   4.740000  ...   0.0  0.0  0.0         1400.0
# ...          ...   ...    ...        ...  ...   ...  ...  ...            ...
# 98156  72.320000  0.00   9.99   0.050000  ...   0.0  0.0  0.0         1500.0
# 98157  72.320000  0.00   9.99   0.050000  ...   0.0  0.0  0.0         1600.0
# 98158  66.629997  0.00  13.77  16.290001  ...   0.0  0.0  0.0         1400.0
# 98159  66.629997  0.00  13.77  16.290001  ...   0.0  0.0  0.0         1500.0
# 98160  66.629997  0.00  13.77  16.290001  ...   0.0  0.0  0.0         1600.0
#
# [19720 rows x 54 columns]

# %%
training = viscosity.iloc[14790:93231,X_idx]
training
# Out:
#             SiO2  B2O3  Al2O3   MgO   CaO  ...  SO3  MoO3  WO3  H2O  Temperature_C
# 14790   0.000000  64.0   0.00  0.00  0.00  ...  0.0   0.0  0.0  0.0          773.0
# 14791   0.000000  62.0   0.00  0.00  0.00  ...  0.0   0.0  0.0  0.0          840.0
# 14792   0.000000  61.0   0.00  0.00  0.00  ...  0.0   0.0  0.0  0.0          875.0
# 14793   0.000000  60.0   0.00  0.00  0.00  ...  0.0   0.0  0.0  0.0          895.0
# 14794   0.000000  56.0   0.00  0.00  0.00  ...  0.0   0.0  0.0  0.0          947.0
# ...          ...   ...    ...   ...   ...  ...  ...   ...  ...  ...            ...
# 93226  66.419998   0.3  14.69  5.53  6.95  ...  0.0   0.0  0.0  0.0         1200.0
# 93227  66.419998   0.3  14.69  5.53  6.95  ...  0.0   0.0  0.0  0.0         1300.0
# 93228  66.419998   0.3  14.69  5.53  6.95  ...  0.0   0.0  0.0  0.0         1400.0
# 93229  66.419998   0.3  14.69  5.53  6.95  ...  0.0   0.0  0.0  0.0         1500.0
# 93230  66.419998   0.3  14.69  5.53  6.95  ...  0.0   0.0  0.0  0.0         1600.0
#
# [78441 rows x 54 columns]

# %%
training_remove = list((np.argwhere(np.isnan(np.array(training.iloc[:,53]))).reshape(-1))+14790)

# %%
len(training_remove)
# Out:
# 27

# %%
|X_traindf = training.drop(training_remove)

# %%
np.argwhere(np.isnan(np.array(X_traindf.iloc[:,53]))).reshape(-1)
# Out:
# array([], dtype=int64)

# %%
y_traindf = viscosity.iloc[14790:93231,54].drop(training_remove)
np.isnan(y_traindf).sum()
# Out:
# 0

# %%
testing_remove = list((np.argwhere(np.isnan(np.array(testing.iloc[:,53]))).reshape(-1)))

# %%
X_testdf = testing.drop(testing_remove)

# %%
np.argwhere(np.isnan(np.array(X_testdf.iloc[:,53]))).reshape(-1)
# Out:
# array([], dtype=int64)

# %%
y_testdf = viscosity.drop(range(14790,93231)).iloc[:,54].drop(testing_remove)
np.isnan(y_testdf).sum()
# Out:
# 0

# %%
X_train = np.array(X_traindf)

# %%
y_train = np.array(y_traindf).reshape(-1)

# %%
X_train = torch.tensor(X_train, device="cuda").type(torch.float)
y_train = torch.tensor(y_train, device="cuda").type(torch.float)

# %%
X_mean = X_train.mean(dim=0)
X_std = X_train.std(dim=0)
y_mean = y_train.mean(dim=0)
y_std = y_train.std(dim=0)
X_mean.shape, X_std.shape, y_mean.shape, y_std.shape
# Out:
# (torch.Size([54]), torch.Size([54]), torch.Size([]), torch.Size([]))

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y, transform=None, target_transform=None):
        super().__init__()
        self.X = X
        self.y = y
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        X = self.X[idx]
        y = self.y[idx]

        if self.transform:
            X = self.transform(X)

        if self.target_transform is not None:
            y = self.target_transform(y)
        return X, y

# %%
training_set = CustomDataset(X_train, 
                             y_train, 
                             transform=lambda X: ((X - X_mean)/X_std), 
                             target_transform=lambda y: ((y - y_mean)/y_std)
                          )

# %%
net = torch.nn.Sequential(
    torch.nn.Linear(54, 256),
    torch.nn.BatchNorm1d(256),
    torch.nn.ReLU(),
    torch.nn.Dropout(p=0.1),
    torch.nn.Linear(256, 512),
    torch.nn.BatchNorm1d(512),
    torch.nn.ReLU(),  
    torch.nn.Dropout(p=0.1),   
    torch.nn.Linear(512, 256),
    torch.nn.BatchNorm1d(256),
    torch.nn.ReLU(),  
    torch.nn.Dropout(p=0.1),
    torch.nn.Linear(256, 128),
    torch.nn.BatchNorm1d(128),
    torch.nn.ReLU(),  
    torch.nn.Dropout(p=0.1),
    torch.nn.Linear(128, 64),
    torch.nn.BatchNorm1d(64),
    torch.nn.ReLU(),  
    torch.nn.Dropout(p=0.1),
    torch.nn.Linear(64, 1))

batch_size = 128
epoch_total = 100


def lr_lambda(epoch):
 
    lr=0.01    
    return lr

optimizer = torch.optim.Adam([param for param in net.parameters() if param.requires_grad], lr=0.01, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

loss_func = torch.nn.MSELoss(reduction="none") 

train_loader = DataLoader(
    dataset=training_set,
    batch_size=batch_size, 
    shuffle=True)



net = net.cuda()

train_losses = []
train_r2 = []
# start training

for epoch in range(epoch_total):
    # print('Epoch = %d' % epoch + 1)
    net.train()
    train_targets = []
    train_predictions = []
    total_loss = None
    for step, (batch_X, batch_y) in enumerate(train_loader): # for each training step
        optimizer.zero_grad()   # clear gradients for next train
        prediction = net(batch_X).squeeze(dim=1) 
          # input x and predict based on x
        loss = loss_func(prediction, batch_y)     # must be (1. nn output, 2. target)
        current_loss = loss.sum()

        if total_loss is None:
            total_loss = current_loss
        else:
            total_loss += current_loss
        
        loss = loss.mean()
        loss.backward()         # backpropagation, compute gradients
        optimizer.step()        # apply gradients
        train_targets += [batch_y]
        train_predictions += [prediction]
    
    with torch.no_grad():
        train_targets = torch.cat(train_targets, dim=0)
        train_predictions = torch.cat(train_predictions, dim=0)
        total_loss = total_loss / train_targets.shape[0]
        train_losses += [total_loss.item()]
        train_r2.append(sklearn.metrics.r2_score((train_targets * y_std + y_mean).cpu().numpy(), (train_predictions * y_std + y_mean).cpu().numpy()))
        print('Epoch %d: Training Loss = %.4f' % (epoch + 1, total_loss.item()))


    lr_scheduler.step()
# Out:
# Epoch 1: Training Loss = 0.3217
# Epoch 2: Training Loss = 0.1942
# Epoch 3: Training Loss = 0.1647
# Epoch 4: Training Loss = 0.1517
# Epoch 5: Training Loss = 0.1408
# Epoch 6: Training Loss = 0.1301
# Epoch 7: Training Loss = 0.1252
# Epoch 8: Training Loss = 0.1191
# Epoch 9: Training Loss = 0.1171
# Epoch 10: Training Loss = 0.1114
# Epoch 11: Training Loss = 0.1097
# Epoch 12: Training Loss = 0.1063
# Epoch 13: Training Loss = 0.1030
# Epoch 14: Training Loss = 0.1009
# Epoch 15: Training Loss = 0.0961
# Epoch 16: Training Loss = 0.0990
# Epoch 17: Training Loss = 0.0954
# Epoch 18: Training Loss = 0.0932
# Epoch 19: Training Loss = 0.0912
# Epoch 20: Training Loss = 0.0907
# Epoch 21: Training Loss = 0.0896
# Epoch 22: Training Loss = 0.0906
# Epoch 23: Training Loss = 0.0865
# Epoch 24: Training Loss = 0.0866
# Epoch 25: Training Loss = 0.0852
# Epoch 26: Training Loss = 0.0838
# Epoch 27: Training Loss = 0.0820
# Epoch 28: Training Loss = 0.0819
# Epoch 29: Training Loss = 0.0832
# Epoch 30: Training Loss = 0.0807
# Epoch 31: Training Loss = 0.0808
# Epoch 32: Training Loss = 0.0797
# Epoch 33: Training Loss = 0.0807
# Epoch 34: Training Loss = 0.0785
# Epoch 35: Training Loss = 0.0777
# Epoch 36: Training Loss = 0.0776
# Epoch 37: Training Loss = 0.0768
# Epoch 38: Training Loss = 0.0761
# Epoch 39: Training Loss = 0.0755
# Epoch 40: Training Loss = 0.0781
# Epoch 41: Training Loss = 0.0733
# Epoch 42: Training Loss = 0.0730
# Epoch 43: Training Loss = 0.0742
# Epoch 44: Training Loss = 0.0735
# Epoch 45: Training Loss = 0.0715
# Epoch 46: Training Loss = 0.0718
# Epoch 47: Training Loss = 0.0737
# Epoch 48: Training Loss = 0.0724
# Epoch 49: Training Loss = 0.0706
# Epoch 50: Training Loss = 0.0711
# Epoch 51: Training Loss = 0.0705
# Epoch 52: Training Loss = 0.0691
# Epoch 53: Training Loss = 0.0685
# Epoch 54: Training Loss = 0.0695
# Epoch 55: Training Loss = 0.0708
# Epoch 56: Training Loss = 0.0689
# Epoch 57: Training Loss = 0.0689
# Epoch 58: Training Loss = 0.0673
# Epoch 59: Training Loss = 0.0681
# Epoch 60: Training Loss = 0.0683
# Epoch 61: Training Loss = 0.0677
# Epoch 62: Training Loss = 0.0665
# Epoch 63: Training Loss = 0.0663
# Epoch 64: Training Loss = 0.0666
# Epoch 65: Training Loss = 0.0664
# Epoch 66: Training Loss = 0.0666
# Epoch 67: Training Loss = 0.0636
# Epoch 68: Training Loss = 0.0655
# Epoch 69: Training Loss = 0.0652
# Epoch 70: Training Loss = 0.0640
# Epoch 71: Training Loss = 0.0662
# Epoch 72: Training Loss = 0.0639
# Epoch 73: Training Loss = 0.0639
# Epoch 74: Training Loss = 0.0649
# Epoch 75: Training Loss = 0.0627
# Epoch 76: Training Loss = 0.0636
# Epoch 77: Training Loss = 0.0622
# Epoch 78: Training Loss = 0.0630
# Epoch 79: Training Loss = 0.0623
# Epoch 80: Training Loss = 0.0622
# Epoch 81: Training Loss = 0.0625
# Epoch 82: Training Loss = 0.0612
# Epoch 83: Training Loss = 0.0619
# Epoch 84: Training Loss = 0.0621
# Epoch 85: Training Loss = 0.0604
# Epoch 86: Training Loss = 0.0618
# Epoch 87: Training Loss = 0.0596
# Epoch 88: Training Loss = 0.0611
# Epoch 89: Training Loss = 0.0606
# Epoch 90: Training Loss = 0.0596
# Epoch 91: Training Loss = 0.0593
# Epoch 92: Training Loss = 0.0603
# Epoch 93: Training Loss = 0.0602
# Epoch 94: Training Loss = 0.0604
# Epoch 95: Training Loss = 0.0597
# Epoch 96: Training Loss = 0.0572
# Epoch 97: Training Loss = 0.0577
# Epoch 98: Training Loss = 0.0589
# Epoch 99: Training Loss = 0.0582
# Epoch 100: Training Loss = 0.0587

# %%
X_test = np.array(X_testdf)

# %%
y_test = np.array(y_testdf).reshape(-1)

# %%
X_test = torch.tensor(X_test, device="cuda").type(torch.float)
y_test = torch.tensor(y_test, device="cuda").type(torch.float)

# %%
test_set = CustomDataset(X_test,
                        y_test,
                        transform=lambda X: ((X - X_mean)/X_std), 
                        target_transform=lambda y: ((y - y_mean)/y_std)
                    )

# %%
test_r2=[]
test_losses=[]

# %%
test_loader = DataLoader(
    dataset=test_set,
    batch_size=batch_size, 
    shuffle=False)

with torch.no_grad():
    net.eval()
    test_targets = []
    test_predictions = []
    total_loss = None
    for (batch_X, batch_y) in test_loader: # for each training step
        prediction = net(batch_X).squeeze(dim=1)     # input x and predict based on x
        current_loss = loss_func(prediction, batch_y).sum()
        if total_loss is None:
            total_loss = current_loss
        else:
            total_loss += current_loss
        test_targets += [batch_y]
        test_predictions += [prediction]
    test_targets = torch.cat(test_targets, dim=0)
    test_predictions = torch.cat(test_predictions, dim=0)
    test_r2.append(sklearn.metrics.r2_score((test_targets * y_std + y_mean).cpu().numpy(), (test_predictions * y_std + y_mean).cpu().numpy()))
    
    total_loss = total_loss / test_targets.shape[0]
    test_losses.append(total_loss.item())
    print("Epoch %d: Validation Loss = %.4f" % (epoch + 1, total_loss.item()))
# Out:
# Epoch 100: Validation Loss = 0.4239

# %%
test_r2
# Out:
# [0.7822297583182907]

# %%
train_r2
# Out:
# [0.6782584954614748,
#  0.8058314731912467,
#  0.8352900399606068,
#  0.8482829795989577,
#  0.85920242174791,
#  0.8698931007105652,
#  0.8747602989198093,
#  0.8809266834444779,
#  0.8828686873556626,
#  0.88863442873093,
#  0.8902779062444101,
#  0.8937402810856128,
#  0.8970436608444952,
#  0.8991337728843806,
#  0.9038632185866463,
#  0.9009768185204649,
#  0.9046449707353421,
#  0.9067635133399529,
#  0.9088205603792117,
#  0.9092618774214822,
#  0.9104048301360178,
#  0.9094299007954222,
#  0.9135144133450581,
#  0.913395980004481,
#  0.9147497292102228,
#  0.9161509102284454,
#  0.9179502236039846,
#  0.918077509319831,
#  0.916846346297794,
#  0.919308120730199,
#  0.9191845441346784,
#  0.9202733402110737,
#  0.9193229282531867,
#  0.9215158821994293,
#  0.9222636021065292,
#  0.9223958216303128,
#  0.9232443420014738,
#  0.9239201375198041,
#  0.9244493771045657,
#  0.9219116501370914,
#  0.9267212822608154,
#  0.9270465099163665,
#  0.9257966823852308,
#  0.9264707741775772,
#  0.9285417894614119,
#  0.9282330858961608,
#  0.9263091152486129,
#  0.9276182482938229,
#  0.9294166359219431,
#  0.9289051719581709,
#  0.9294925681416573,
#  0.9308998004687621,
#  0.9314729303238761,
#  0.9304926291125848,
#  0.9292459513617661,
#  0.9310829924434909,
#  0.9311312704091971,
#  0.9327056589100068,
#  0.9319457934069272,
#  0.9317402093088258,
#  0.9322924201682888,
#  0.9335160896070571,
#  0.9337352711094746,
#  0.933405263416819,
#  0.9335617953377662,
#  0.9334450638006071,
#  0.9363828209140168,
#  0.934534842760977,
#  0.9347604721687711,
#  0.9360418939399746,
#  0.9337757554368715,
#  0.9360687114162557,
#  0.9361442323678162,
#  0.9351081096345923,
#  0.9373307843811164,
#  0.9363891658425998,
#  0.9377870065697766,
#  0.9370492002777852,
#  0.9376698253045639,
#  0.9377712367987755,
#  0.9374954039904808,
#  0.9387597959085324,
#  0.93808206895642,
#  0.9379322218087887,
#  0.9395745981280532,
#  0.9382460314348501,
#  0.9403988426874131,
#  0.9388894721957367,
#  0.9394012167823493,
#  0.9404210943863855,
#  0.9407329461206253,
#  0.9396816250343398,
#  0.9398347729282499,
#  0.9396372297238116,
#  0.9402639305012724,
#  0.9428438747117976,
#  0.9423212376388841,
#  0.9410915930963564,
#  0.9417737553952388,
#  0.9412673360021271]

# %%
plt.plot(train_r2, label="Training R2 Score")
plt.ylabel('R2 Score/Loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

plt.plot(train_losses, label="Training Loss")
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
plt.plot((test_targets * y_std + y_mean).cpu().numpy(), (test_predictions * y_std + y_mean).cpu().numpy(),'bo')
plt.plot([-3,13],[-3,13],'red'
)

# %%
plt.plot((train_targets * y_std + y_mean).cpu().numpy(), (train_predictions * y_std + y_mean).cpu().numpy(),'bo')
plt.plot([-3,13],[-3,13],'red'
)
